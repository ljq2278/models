# %%
import numpy as np
import skimage
from skimage import data,exposure,io
import matplotlib
import matplotlib.pyplot as plt

# matplotlib.use('Qt5Agg')

image_ori = io.imread(r'D:\dataset\traffic_state_predict\amap_traffic_train_0712\000001\3.jpg')
image = exposure.equalize_hist(image_ori)
# Out:
# d:\anaconda3\envs\py36\lib\site-packages\skimage\exposure\exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)

# %%
ori_arr0=image_ori[:,:,0].flatten()
ori_arr1=image_ori[:,:,1].flatten()
ori_arr2=image_ori[:,:,2].flatten()

plt.figure("hist")

plt.subplot(241)
plt.hist(ori_arr0, bins=256, normed=1,edgecolor='None',facecolor='red') #原始图像直方图
plt.subplot(242)
plt.hist(ori_arr1, bins=256, normed=1,edgecolor='None',facecolor='green') #原始图像直方图
plt.subplot(243)
plt.hist(ori_arr2, bins=256, normed=1,edgecolor='None',facecolor='blue') #原始图像直方图
plt.subplot(244)
plt.imshow(image_ori) #原始图像

img0 = exposure.equalize_hist(image_ori[:,:,0])
img1 = exposure.equalize_hist(image_ori[:,:,1])
img2 = exposure.equalize_hist(image_ori[:,:,2])
img = np.stack([img0,img1,img2],axis=2)
arr0 = img0.flatten()
arr1 = img1.flatten()
arr2 = img2.flatten()


plt.subplot(245)
plt.hist(arr0, bins=256, normed=1,edgecolor='None',facecolor='red') #变换图像直方图
plt.subplot(246)
plt.hist(arr1, bins=256, normed=1,edgecolor='None',facecolor='green') #变换图像直方图
plt.subplot(247)
plt.hist(arr2, bins=256, normed=1,edgecolor='None',facecolor='blue') #变换图像直方图
plt.subplot(248)
plt.imshow(img) #变换图
io.imsave('img.png',img)

plt.show()
# Out:
# d:\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:11: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   # This is added back by InteractiveShellApp.init_path()
# d:\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   del sys.path[0]
# d:\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   from ipykernel import kernelapp as app
# d:\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:29: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# ...
